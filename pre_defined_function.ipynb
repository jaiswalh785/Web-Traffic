# %%
import os

# %%
os.getcwd() # display the current working directory
# Out:
# 'c:\\vscode\\PYTHON'

# %%
os.mkdir("codes") # create a directory

# %%
if os.path.exists('codes'):
    print('The directory exists')
else:
    os.mkdir('codes')
# Out:
# The directory exists

# %%
os.listdir() # list all the files and directories in the current
# Out:
# ['basics.ipynb',
#  'classes.ipynb',
#  'codes',
#  'dictionary.ipynb',
#  'functions.ipynb',
#  'hello.py',
#  'list.ipynb',
#  'list_adv.ipynb',
#  'loops.ipynb',
#  'pre_defined_function.ipynb',
#  'pythonstrings.ipynb',
#  'sets.ipynb',
#  'strings.ipynb',
#  'tuple.ipynb']

# %%
window_content = os.listdir('c:\windows')
print(f'{len(window_content)} items in the directory')
print(window_content)
# Out:
# 108 items in the directory
# ['addins', 'appcompat', 'apppatch', 'AppReadiness', 'assembly', 'bcastdvr', 'bfsvc.exe', 'BitLockerDiscoveryVolumeContents', 'Boot', 'bootstat.dat', 'Branding', 'CbsTemp', 'Containers', 'CSC', 'Cursors', 'debug', 'diagnostics', 'DiagTrack', 'DigitalLocker', 'Downloaded Program Files', 'DtcInstall.log', 'ELAMBKUP', 'en-US', 'explorer.exe', 'Firmware', 'Fonts', 'GameBarPresenceWriter', 'Globalization', 'Help', 'HelpPane.exe', 'hh.exe', 'IdentityCRL', 'IME', 'ImmersiveControlPanel', 'INF', 'InputMethod', 'Installer', 'L2Schemas', 'LanguageOverlayCache', 'LiveKernelReports', 'Logs', 'lsasetup.log', 'Media', 'mib.bin', 'Microsoft.NET', 'Migration', 'ModemLogs', 'notepad.exe', 'OCR', 'Offline Web Pages', 'OpenDrive.exe', 'Packages', 'Panther', 'Performance', 'PFRO.log', 'PLA', 'PolicyDefinitions', 'Prefetch', 'PrintDialog', 'Professional.xml', 'Provisioning', 'py.exe', 'pyshellext.amd64.dll', 'pyw.exe', 'regedit.exe', 'Registration', 'RemotePackages', 'rescache', 'Resources', 'SchCache', 'schemas', 'security', 'ServiceProfiles', 'ServiceState', 'servicing', 'Setup', 'setupact.log', 'setuperr.log', 'ShellComponents', 'ShellExperiences', 'SKB', 'SoftwareDistribution', 'Speech', 'Speech_OneCore', 'splwow64.exe', 'System', 'system.ini', 'System32', 'SystemApps', 'SystemResources', 'SystemTemp', 'SysWOW64', 'TAPI', 'Tasks', 'Temp', 'tracing', 'twain_32', 'twain_32.dll', 'Vss', 'WaaS', 'Web', 'win.ini', 'WindowsShell.Manifest', 'WindowsUpdate.log', 'winhlp32.exe', 'WinSxS', 'WMSysPr9.prx', 'write.exe']

# %%
images = os.listdir("D:/Users/HP 346 G3/OneDrive/Pictures")

# %%
os.path.splitext(images[0])

# %%
png_images = [file for file in images if file.endswith('.png')]
print(png_images)

# %%
import requests

# %%
page = requests.get('https://en.wikipedia.org/wiki/Catatos')
page

# %%
page.text

# %%
import random

# %%
random.random()
# Out:
# 0.4204314829921345

# %%
random.randint(1,10)
# Out:
# 9

# %%
dice_value = random.randint(1,6)
if dice_value==6:
    print('you win')
else:
    print('try again,loser')
# Out:
# you win

# %%
print('you win') if random.randint(1,6)==6 else print('try again, loser')
# Out:
# try again, loser

# %%
while True:
    dice_value = random.randint(1,6)
    if dice_value==6:
        print('you win')
        break
    else:
        print('try again,loser! you got',dice_value)
# Out:
# try again,loser! you got 4
# try again,loser! you got 1
# try again,loser! you got 5
# try again,loser! you got 4
# try again,loser! you got 3
# try again,loser! you got 1
# try again,loser! you got 2
# try again,loser! you got 1
# try again,loser! you got 5
# you win

# %%
emojis = ['❤','😍','😒','👌','👍','😁','💕']

# %%
print(random.choice(emojis))
# Out:
# 😁

# %%
print(random.choices(emojis, k=5))
# Out:
# ['💕', '❤', '👌', '😍', '💕']

# %%
print(random.choices(emojis, k=3))
# Out:
# ['👍', '👍', '👌']

# %%
import math

# %%
math.factorial(5)
# Out:
# 120

# %%
math.hypot(3,4)
# Out:
# 5.0

# %%
math.sin(10)
# Out:
# -0.5440211108893698

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.degrees(math.sin(30))
# Out:
# -56.61004208597725

# %%
math.gcd(2,3,5,17)
# Out:
# 1

# %%
math.sqrt?
# Out:
# Signature: math.sqrt(x, /)
# Docstring: Return the square root of x.
# Type:      builtin_function_or_method

# %% [markdown]
# goto anaconda prompt shell and run the command
# ```
# 'Syntax'
# ```
# pip install <libary>
# ```
# ex:
# ```
# pip install pillow

# %%
from PIL import Image

# %%
im = Image.open("C:/Users/Harsh/Downloads/R.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630 at 0x2B9375272B0>

# %%
im = Image.open("C:/Users/Harsh/Downloads/R.jpg").resize((400,300))
im.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x2B93933C460>

# %% [markdown]
# ```
# pip install BeautifulSoup4

# %%
from bs4 import BeautifulSoup

# %%
page = request.get('https://en.wikipedia.org/wiki/Python')
soup = BeautifulSoup(page.text)
print(soup.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\vscode\PYTHON\pre_defined_function.ipynb Cell 42' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/vscode/PYTHON/pre_defined_function.ipynb#ch0000047?line=0'>1</a> page = request.get('https://en.wikipedia.org/wiki/Python')
#       <a href='vscode-notebook-cell:/c%3A/vscode/PYTHON/pre_defined_function.ipynb#ch0000047?line=1'>2</a> soup = BeautifulSoup(page.text)
#       <a href='vscode-notebook-cell:/c%3A/vscode/PYTHON/pre_defined_function.ipynb#ch0000047?line=2'>3</a> print(soup.text)
#
# NameError: name 'request' is not defined
